# %% [markdown]
# # 🎮 Build a Python Quiz Game
#
# You're going to build a working quiz game from scratch — one piece at a time.
#
# This isn't a tutorial where you follow instructions and copy code. You'll write the logic yourself, make decisions, and probably hit a few walls. That's the point. The goal is that by the end, you actually understand how it works — not just that it runs.
#
# ---
#
# ### Before you start — a note on using Claude
#
# You have Claude Chat open on the side. Use it — but use it well.
#
# **The trap:** Asking *"write the check_answer function for me"* will get you working code in seconds. But when something breaks later, you won't know where to start. This is probably a familiar feeling.
#
# **A better approach:** Use Claude to understand *why*, not just *what*. The cells below suggest specific questions to ask — they're designed to build your understanding, not hand you the answer. If Claude gives you complete code you don't understand, ask: *"Can you explain what each line does instead of just giving me the solution?"*
#
# Claude can also be wrong. If something doesn't make sense or doesn't work, trust that instinct and push back.
#
# ---
#
# ### How to use this notebook
# - **Shift + Enter** runs a cell (or click ▶)
# - `# YOUR CODE HERE` = your task
# - **🤔 Think first** = reason it through before typing anything
# - **💬 Ask Claude** = a specific, scoped question designed to help you understand
# - The order matters — each part builds on the one before it
#
# ---
#
# ### What you're building
# | Part | What you implement |
# |------|-------------------|
# | 1 | Store questions in a Python dictionary |
# | 2 | Display a formatted question (given — read and understand it) |
# | 3 | Check if an answer is correct |
# | 4 | Run the full quiz loop |
# | 5 | Show a results summary |
# | 6 | Play it! |
# | ★ Bonus | Shuffle the question order |

# %% [markdown]
# ---
# ## Part 1 — Storing Your Questions 📂
#
# You need somewhere to store questions and their answers. Python has a data structure called a **dictionary** — it maps a *key* to a *value*, like a lookup table.
#
# ```python
# phone_book = {
#     "Alice": "0412 345 678",
#     "Bob":   "0412 987 654",
# }
# # phone_book["Alice"] → "0412 345 678"
# ```
#
# 🤔 **Think before you look at the starter code:**
# For a quiz, which should be the key — the question or the answer? Why does that direction make sense?
#
# *(If you're not sure, think about how you'd actually use it: "given a question, look up its answer" or "given an answer, look up its question"?)*
#
# ---
#
# **Your task:** Five questions are provided. Add at least 3 more of your own at the bottom. They can be about anything.

# %%
# Each entry: "question string" → "correct answer string"
# Answers are all lowercase — we'll handle capitalisation in Part 3.

quiz_questions = {
    "What keyword defines a function in Python?": "def",
    "What method adds an item to the end of a Python list?": "append",
    "What does len([]) return?": "0",
    "What symbol starts a comment in Python?": "#",
    "What is the output of 10 // 3?": "3",
    # ── Add your questions below this line ──────────────────────
    # "Your question here?": "your answer",
}

print(f"Quiz loaded with {len(quiz_questions)} questions.")

# %% [markdown]
# ---
# ## Part 2 — Displaying a Question 🖨️
#
# This function is **already written** — your job here is to read it, understand what each line does, and run it.
#
# Before running, look at the function and answer these for yourself:
# - What are the three inputs (parameters) it takes?
# - What does `"─" * 45` produce? Why would you do that?
# - What's an f-string — what do the curly braces `{}` do inside it?
#
# 💬 **Ask Claude (if stuck):** *"What is an f-string in Python and why would I use it instead of normal string concatenation?"*
# Ask for the *why*, not just a definition.

# %%
def show_question(question_text, question_number, total_questions):
    """Prints a formatted question to the screen."""
    print("\n" + "─" * 45)
    print(f"  Question {question_number} of {total_questions}")
    print(f"\n  {question_text}")
    print("─" * 45)

# Test it — does the output look right?
show_question("What keyword defines a function in Python?", 1, 8)

# %% [markdown]
# ---
# ## Part 3 — Checking an Answer ✅
#
# This is the first function **you write**.
#
# The function takes two strings — what the user typed, and what the correct answer is — and returns `True` or `False`.
#
# 🤔 **Think through these cases before writing a single line of code:**
#
# | User types | Correct answer | Should it pass? |
# |---|---|---|
# | `"def"` | `"def"` | Yes — exact match |
# | `"Def"` | `"def"` | Yes — same word, different case |
# | `"DEF"` | `"def"` | Yes — same word, all caps |
# | `"  def  "` | `"def"` | Yes — accidental spaces |
# | `"define"` | `"def"` | No — wrong answer |
#
# The first four all come down to: how do you make Python ignore capitalisation and extra spaces?
#
# 💬 **Ask Claude:** *"What Python string methods let me remove whitespace from both ends of a string, and convert it to lowercase? Show me just the method names and a one-line example of each — don't write the function for me."*
#
# > 🎯 Your whole implementation should be **1–2 lines** inside the function.

# %%
def check_answer(user_answer, correct_answer):
    """
    Returns True if user_answer matches correct_answer,
    ignoring capitalisation and leading/trailing spaces.
    """
    # YOUR CODE HERE
    pass


# ── Run these tests — all five should print True ──────────────────────────────
print(check_answer("def",     "def"))           # exact
print(check_answer("DEF",     "def"))           # all caps
print(check_answer("  def ",  "def"))           # spaces
print(check_answer("Append",  "append"))        # mixed case
print(check_answer("wrong",   "def") == False)  # wrong answer → False

# %% [markdown]
# ---
# ## Part 4 — The Quiz Loop 🔄
#
# This is where the game actually runs. A skeleton is provided — you fill in the two marked sections.
#
# 🤔 **Think through the logic before touching the code:**
#
# 1. How do you loop over a dictionary's keys and values at the same time?
# 2. After getting the user's answer, you have `user_answer` and `correct_answer`. What do you do with them? (You already built the tool for this.)
# 3. What needs to happen to `score` when the user is right? When they're wrong?
#
# 💬 **Ask Claude (only if stuck on the loop):** *"How do I loop over both keys and values in a Python dictionary at the same time? Just show me the syntax, not a full example."*
#
# ---
#
# **One concept you'll need — `enumerate()`:**
# ```python
# for i, item in enumerate(["a", "b", "c"]):
#     print(i, item)
# # prints: 0 a  /  1 b  /  2 c
# ```
# It gives you the index and the item at the same time. Useful for "Question 1 of 8."

# %%
def run_quiz(questions):
    """Runs through all questions and returns the final score."""
    score = 0
    question_list = list(questions.items())  # list of (question, answer) pairs
    total = len(question_list)

    print("\n" + "═" * 45)
    print("  🎮  Python Quiz — Good luck!")
    print(f"  {total} questions.")
    print("═" * 45)

    for i, (question, correct_answer) in enumerate(question_list):

        show_question(question, i + 1, total)
        user_answer = input("  Your answer: ")

        # TODO 1 ─────────────────────────────────────────────────────────────────
        # Use check_answer() to decide if the user was right or wrong.
        # If correct:  print a short message and add 1 to score.
        # If wrong:    print the correct answer so they can learn from it.
        # (aim for about 5 lines)
        # YOUR CODE HERE

    # TODO 2 ─────────────────────────────────────────────────────────────────────
    # After the loop ends, print how many the user got right.
    # Example: "\nYou answered 4 out of 8 correctly."
    # YOUR CODE HERE

    return score


# ── Come back and uncomment this once check_answer() is working ───────────────
# final_score = run_quiz(quiz_questions)

# %% [markdown]
# ---
# ## Part 5 — Results Summary 🏆
#
# Once the quiz finishes, show the user how they did.
#
# 🤔 **Work through these questions before writing:**
#
# 1. What's the formula for percentage? *(score ÷ total × 100)*
# 2. What happens if `total` is 0? Try it in your head: `0 / 0` — what does Python do with that? How do you protect against it?
# 3. What's the percentage cutoff for each performance tier?
#
# 💬 **Ask Claude (for Q2 only if needed):** *"What happens in Python when you divide by zero, and what's a concise way to check for that before it happens?"*
# Ask for the *what and why*, not a code snippet.
#
# ---
#
# **Performance messages:**
#
# | Score | Message |
# |---|---|
# | 90%+ | `"Outstanding — you really know this. 🌟"` |
# | 70–89% | `"Solid work. A couple more runs and you'll nail it. 👍"` |
# | 50–69% | `"Good effort. Review the ones you missed and try again. 📚"` |
# | Below 50% | `"Keep going — everyone starts somewhere. 💪"` |

# %%
def show_results(score, total):
    """Prints the final score and a performance message."""
    print("\n" + "═" * 45)
    print("  📊  RESULTS")
    print("═" * 45)

    # TODO 1 — Handle the edge case: what if total is 0?
    # YOUR CODE HERE

    # TODO 2 — Calculate the percentage
    # YOUR CODE HERE

    # TODO 3 — Print the score line
    # Example: "  You got 4 out of 8 correct (50.0%)"
    # YOUR CODE HERE

    # TODO 4 — Print the performance message based on percentage
    # YOUR CODE HERE


# ── Test it with known inputs ─────────────────────────────────────────────────
show_results(8, 8)   # 100% → Outstanding
show_results(6, 8)   # 75%  → Solid work
show_results(4, 8)   # 50%  → Good effort
show_results(2, 8)   # 25%  → Keep going
show_results(0, 0)   # Edge case — no questions loaded

# %% [markdown]
# ---
# ## Part 6 — Play It 🚀
#
# All the pieces are built. Run the cell below and play through your own quiz.
#
# Then **deliberately try to break it**:
# - Leave the answer blank and press Enter
# - Type the answer in ALL CAPS
# - Type an answer with spaces at the front
#
# Does it handle those cases the way you'd expect? If not, where would you start looking?

# %%
final_score = run_quiz(quiz_questions)
show_results(final_score, len(quiz_questions))

# %% [markdown]
# ---
# ## ★ Bonus — Shuffle the Questions 🔀
#
# Right now, questions always appear in the same order. Add one line to randomise them.
#
# Python's `random` module has two relevant functions:
# - `random.shuffle(my_list)` — shuffles a list **in place** (modifies the original, returns nothing)
# - `random.sample(my_list, k)` — returns a **new** randomly-ordered list of `k` items
#
# 🤔 **Think before asking:**
# - `question_list` is already a list. Which function fits better here and why?
# - If you use `random.shuffle()`, what do you get back when you write `question_list = random.shuffle(question_list)`? Try to predict it before testing.
#
# 💬 **Ask Claude:** *"What does random.shuffle() return in Python, and why? Don't write the function for me — I just want to understand that specific behaviour."*
#
# **Task:** Copy `run_quiz()` below, rename it `run_shuffled_quiz()`, and add the shuffle — one line, before the loop.

# %%
import random

def run_shuffled_quiz(questions):
    """
    Same as run_quiz(), but questions appear in a different
    random order each time the function is called.
    """
    # YOUR CODE HERE
    pass


# Run it twice — the order should differ each time
# final_score = run_shuffled_quiz(quiz_questions)
# show_results(final_score, len(quiz_questions))

# %% [markdown]
# ---
# ## ★★ Extension — Second Chance with a Hint 💡
#
# If you finish the bonus, try this.
#
# Modify `run_quiz()` so that after a wrong answer, the program:
# 1. Asks: `"Would you like a hint? (y/n)"`
# 2. If `y`: reveals only the **first letter** of the correct answer
# 3. Gives the player **one more attempt**
# 4. A correct second attempt scores **0.5** instead of 1
#
# 🤔 **Think through the structure before writing:**
# - Where in the existing loop does this new logic go?
# - How do you reveal just the first character of a string? *(Strings work like lists in Python.)*
# - `score` might now be a float (e.g. 4.5 out of 8). Does `show_results()` still work correctly?
#
# 💬 **Ask Claude:** *"If I need to run the same block of code a second time based on user input, is it better to use a nested if-statement, a loop, or something else? Explain the tradeoffs — don't write the code."*

# %%
def run_quiz_with_hints(questions):
    """
    Like run_quiz(), but wrong answers get a hint + second attempt worth 0.5 points.
    """
    # YOUR CODE HERE
    pass


# final_score = run_quiz_with_hints(quiz_questions)
# show_results(final_score, len(quiz_questions))
